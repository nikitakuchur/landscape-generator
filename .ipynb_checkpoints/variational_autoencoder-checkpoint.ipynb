# %%
import torch
import torchvision
from torch import nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

from PIL import Image
import os

# %%
class ImagesDataset(Dataset):
    
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.img_names = os.listdir(root_dir)
        self.data_transforms = transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomVerticalFlip(),
            transforms.ToTensor()])
        
    def __getitem__(self, index):
        img = Image.open(self.root_dir + '/' + self.img_names[index]).convert('L')
        item = self.data_transforms(img)
        img.close()
        display(transforms.ToPILImage()(item.view(64, 64)))
        min = item.min()
        max = item.max()
        if min != max:
            item = (item - min) / (max - min)
        display(transforms.ToPILImage()(item.view(64, 64)))
        return item.view(1, 64, 64)

    def __len__(self):
        return len(self.img_names)

# %%
import matplotlib.pyplot as plt

dataset = ImagesDataset('./data')
display(transforms.ToPILImage()(dataset[0].view(64, 64)))
p = plt.imshow(dataset[0].view(64, 64))
plt.colorbar(p)
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x23E5770ACC8>

# %%
dataloader = DataLoader(dataset, batch_size=100, shuffle=True)

# %%
def double_cnn(in_n, out_n):
    return nn.Sequential(
        nn.Conv2d(in_n, out_n, 3, padding=1),
        nn.ReLU(),
        nn.Conv2d(out_n, out_n, 3, padding=1)
    )

class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        
        # Encoder specification
        self.enc_cnn_1 = double_cnn(1, 32)
        self.enc_cnn_2 = double_cnn(32, 64) 
        self.enc_cnn_3 = double_cnn(64, 128)
        self.enc_cnn_4 = double_cnn(128, 256)
        
        self.enc_linear_1_1 = nn.Linear(4096, 256)
        self.enc_linear_1_2 = nn.Linear(4096, 256)
        
        # Decoder specification
        self.dec_linear_1 = nn.Linear(256, 4096)
        
        self.dec_cnn_1 = double_cnn(256, 128)
        self.dec_cnn_2 = double_cnn(128, 64)
        self.dec_cnn_3 = double_cnn(64, 32)
        self.dec_cnn_4 = double_cnn(32, 1)
        
    def encode(self, data):
        x = self.enc_cnn_1(data)
        x = F.relu(F.max_pool2d(x, 2))
        
        x = self.enc_cnn_2(x)
        x = F.relu(F.max_pool2d(x, 2))
        
        x = self.enc_cnn_3(x)
        x = F.relu(F.max_pool2d(x, 2))
        
        x = self.enc_cnn_4(x)
        x = F.relu(F.max_pool2d(x, 2))
        
        x = x.view(x.size(0), -1)
        return self.enc_linear_1_1(x), self.enc_linear_1_2(x)
    
    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        esp = torch.randn(mu.size()).cuda()
        return mu + std * esp
        
    def decode(self, code):
        out = F.relu(self.dec_linear_1(code))
        out = out.view(out.size(0), 256, 4, 4)
        
        out = F.interpolate(out, 8)
        out = F.relu(self.dec_cnn_1(out))
        
        out = F.interpolate(out, 16)
        out = F.relu(self.dec_cnn_2(out))
        
        out = F.interpolate(out, 32)
        out = F.relu(self.dec_cnn_3(out))
        
        out = F.interpolate(out, 64)
        out = torch.sigmoid(self.dec_cnn_4(out))
        return out
        
    def forward(self, data):
        mu, logvar = self.encode(data)
        code = self.reparametrize(mu, logvar)
        out = self.decode(code)
        return out, mu, logvar

# %%
vae = VAE().cuda()

# %%
x = dataset[400].cuda()
out, _, _ = vae(x.view(1, 1, 64, 64))
plt.imshow(out.view(64, 64).cpu().detach().numpy())
plt.show()

# %%
import torch.optim as optim

def loss_function(recon_x, x, mu, logvar):
    BCE = nn.MSELoss(reduction='sum')(recon_x, x)
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + KLD

optimizer = optim.Adam(vae.parameters(), lr=0.001)

epochs = 100

for epoch in range(epochs):
    vae.train()
    for data in dataloader:
        optimizer.zero_grad()
        x = data.cuda()
        out, mu, logvar = vae(x)
        loss = loss_function(out, x, mu, logvar)
        loss.backward()
        optimizer.step()
    print('epoch=' + str(epoch + 1) + ', loss=' + str(loss))
# Out:
# epoch=1, loss=tensor(228.1899, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=2, loss=tensor(182.1686, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=3, loss=tensor(166.0743, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=4, loss=tensor(198.3823, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=5, loss=tensor(261.6155, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=6, loss=tensor(175.7431, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=7, loss=tensor(229.6932, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=8, loss=tensor(255.8088, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=9, loss=tensor(194.7325, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=10, loss=tensor(177.6826, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=11, loss=tensor(236.9427, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=12, loss=tensor(186.1922, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=13, loss=tensor(199.9811, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=14, loss=tensor(220.4810, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=15, loss=tensor(158.7676, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=16, loss=tensor(158.0233, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=17, loss=tensor(253.7453, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=18, loss=tensor(176.9899, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=19, loss=tensor(235.4949, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=20, loss=tensor(193.6737, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=21, loss=tensor(187.9989, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=22, loss=tensor(147.5620, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=23, loss=tensor(254.5806, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=24, loss=tensor(169.7292, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=25, loss=tensor(205.5123, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=26, loss=tensor(220.1696, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=27, loss=tensor(251.3632, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=28, loss=tensor(229.5379, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=29, loss=tensor(200.9067, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=30, loss=tensor(190.5189, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=31, loss=tensor(165.6907, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=32, loss=tensor(183.7601, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=33, loss=tensor(162.4272, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=34, loss=tensor(154.5459, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=35, loss=tensor(201.1944, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=36, loss=tensor(213.1657, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=37, loss=tensor(231.7974, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=38, loss=tensor(144.3893, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=39, loss=tensor(223.6710, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=40, loss=tensor(163.7960, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=41, loss=tensor(222.2075, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=42, loss=tensor(158.9993, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=43, loss=tensor(158.5185, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=44, loss=tensor(199.4573, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=45, loss=tensor(194.5528, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=46, loss=tensor(198.7920, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=47, loss=tensor(138.6826, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=48, loss=tensor(184.8297, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=49, loss=tensor(144.9690, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=50, loss=tensor(138.5398, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=51, loss=tensor(199.5215, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=52, loss=tensor(213.4898, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=53, loss=tensor(169.6147, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=54, loss=tensor(186.2031, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=55, loss=tensor(218.7113, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=56, loss=tensor(160.3047, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=57, loss=tensor(179.8417, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=58, loss=tensor(184.2574, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=59, loss=tensor(168.6747, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=60, loss=tensor(197.8253, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=61, loss=tensor(189.5948, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=62, loss=tensor(198.7553, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=63, loss=tensor(213.4132, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=64, loss=tensor(319.5351, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=65, loss=tensor(205.2776, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=66, loss=tensor(177.9860, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=67, loss=tensor(153.0689, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=68, loss=tensor(139.5950, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=69, loss=tensor(192.5756, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=70, loss=tensor(154.3307, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=71, loss=tensor(173.8539, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=72, loss=tensor(205.8587, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=73, loss=tensor(204.1670, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=74, loss=tensor(156.8519, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=75, loss=tensor(188.3453, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=76, loss=tensor(192.2255, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=77, loss=tensor(258.1704, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=78, loss=tensor(201.3221, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=79, loss=tensor(173.9630, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=80, loss=tensor(191.7658, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=81, loss=tensor(188.6465, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=82, loss=tensor(248.1644, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=83, loss=tensor(200.3846, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=84, loss=tensor(251.9156, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=85, loss=tensor(182.2992, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=86, loss=tensor(179.8583, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=87, loss=tensor(202.5002, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=88, loss=tensor(142.3517, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=89, loss=tensor(198.6864, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=90, loss=tensor(184.8984, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=91, loss=tensor(166.9620, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=92, loss=tensor(141.1172, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=93, loss=tensor(184.4641, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=94, loss=tensor(201.0110, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=95, loss=tensor(182.7789, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=96, loss=tensor(198.5940, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=97, loss=tensor(155.5443, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=98, loss=tensor(154.3547, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=99, loss=tensor(172.2805, device='cuda:0', grad_fn=<AddBackward0>)
# epoch=100, loss=tensor(190.2510, device='cuda:0', grad_fn=<AddBackward0>)

# %%
torch.cuda.empty_cache()

# %%
x = dataset[400].cuda()
plt.imshow(x.view(64, 64).cpu())
plt.show()
out, _, _ = vae(x.view(1, 1, 64, 64))
plt.imshow(out.view(64, 64).cpu().detach().numpy())
plt.show()

# %%
#torch.save(vae.state_dict(), './variational_autoencoder_save')

# %%
vae.load_state_dict(torch.load('./variational_autoencoder_save'))
# Out:
# <All keys matched successfully>

# %%
xs = []
for data in dataset:
    mu, logvar = vae.encode(data.cuda().view(1, 1, 64, 64))
    code = vae.reparametrize(mu, logvar)
    xs.append(code.cpu().detach()[0])

# %%
codes = torch.cat(xs).view(-1, 256)

# %%
mean = codes.mean(axis=0)
std = codes.std(axis=0)

# %%
mean
# Out:
# tensor([-1.6539e-02,  1.5528e-01, -8.0746e-02, -2.0583e+00,  1.4864e-02,
#          3.6402e-01,  6.0484e-02,  1.5776e-01, -2.6492e-02,  2.5116e-01,
#         -3.0572e-02, -5.7590e-03,  1.1527e-02, -1.8244e-02, -2.1256e-02,
#         -5.0005e-02, -1.3981e-02,  4.4077e-02, -4.0137e-02, -1.1585e-01,
#         -2.7348e-02, -3.0659e-01, -1.7138e-02, -4.8399e-02,  7.0251e-02,
#          4.7709e-02,  2.0554e-02, -2.4836e+00,  6.6797e-03, -1.8084e-01,
#         -1.3583e-02, -7.1770e-02,  1.5186e-01,  2.7322e-02, -6.9020e-02,
#          6.7968e-03,  1.9674e-02,  1.8690e+00, -2.7299e-02,  8.3153e-02,
#          3.2941e-01,  1.6193e-02,  4.3024e-03, -5.0954e-02, -1.9255e+00,
#          3.8411e-02, -7.4061e-03, -3.3544e-03, -1.6902e-01, -2.7312e-02,
#          6.7238e-02, -1.3882e-01,  1.0646e-01,  1.4292e-02,  1.1162e-01,
#         -7.4152e-01,  8.6356e-02,  5.4004e-02,  1.7384e-02, -9.6607e-02,
#          2.3668e-02,  3.1099e-02,  2.4863e-03,  7.2963e-02, -5.2033e-02,
#          3.2818e-02, -3.5572e-02,  2.2994e-02,  7.2058e-02,  4.2845e-02,
#          2.4251e-02,  3.0986e-01, -1.8590e-02,  5.2624e-04, -1.1435e-01,
#          9.7535e-03, -3.7527e-02,  5.9687e-02, -5.6932e-02,  5.6565e-02,
#          4.9293e-03,  2.3642e-02, -5.8985e-03,  1.2557e-02, -2.3449e-02,
#          9.5889e-02, -6.8136e-02, -1.7899e-02,  1.7436e-01,  6.5831e-02,
#         -3.1607e-02, -1.5345e-01,  4.1326e-02, -2.0192e-02,  3.5041e-02,
#          5.3856e-04,  8.7322e-02, -2.6955e-03,  1.2907e-02,  4.6041e-01,
#         1.7822, 0.3745, 0.7907, 0.3178, 0.4661, 0.5291, 0.3081, 0.4467, 0.3792,
#         0.3055, 1.9352, 0.4102, 0.3982, 1.2742, 0.4129, 0.3273, 0.3185, 2.0312,
#         0.3552, 0.3652, 0.3615, 0.7776, 0.3009, 0.3108, 0.6472, 0.4733, 0.3737,
#         0.3239, 0.6852, 0.5414, 0.3059, 0.3183, 0.8760, 0.2972, 0.3074, 0.3249,
#         0.3898, 0.4508, 0.3573, 0.3127, 0.2804, 0.3758, 0.1334, 0.2873, 0.5884,
#         0.4877, 0.4340, 0.3151, 0.2893, 0.6533, 0.3429, 0.4566, 0.3035, 0.3438,
#         0.3292, 0.4092, 0.3146, 0.3386, 0.2985, 0.4132, 0.3846, 0.3770, 0.3585,
#         0.3282, 0.3545, 0.7776, 0.3774, 0.3110, 0.3518, 0.9335, 0.4082, 0.4156,
#         0.5186, 1.6936, 0.2935, 0.2603, 1.7709, 0.3119, 0.5068, 0.4905, 1.4140,
#         0.2759, 0.2875, 0.5028, 0.3293, 0.2970, 0.6104, 0.3505, 0.3288, 0.3434,
#         0.3778, 0.3255, 0.5152, 0.4157, 0.2862, 0.2915, 0.4789, 0.3388, 0.3340,
#         0.2977, 0.3352, 0.3373, 0.3708, 0.4037, 0.7112, 0.3798, 0.2901, 0.6083,
#         1.7458, 0.4613, 0.3072, 0.3266, 0.3450, 0.3216, 0.3154, 0.3804, 0.2935,
#         0.5147, 0.3212, 0.2921, 0.3032, 0.2991, 0.3741, 0.3037, 0.7883, 0.3290,
#         0.3778, 0.3749, 0.4223, 0.2811, 0.4767, 0.3192, 0.2565, 0.3441, 0.3579,
#         0.4518, 0.3198, 0.3629, 0.3288, 0.3401, 0.3636, 0.9186, 0.3239, 0.3147,
#         0.3289, 0.3204, 0.3431, 0.2881, 0.3790, 0.3577, 0.3855, 0.3674, 0.3190,
#         0.3427, 0.4529, 0.7860, 0.4732, 0.3412, 0.3570, 0.3079, 0.4575, 0.4020,
#         0.4205, 0.1250, 0.3175, 0.4891, 0.3990, 0.7846, 0.3413, 0.3410, 0.3237,
#         0.4718, 0.2761, 0.2979, 0.4607, 0.3581, 0.3349, 1.9272, 0.3077, 0.2743,
#         0.3091, 0.3061, 0.4195, 1.3598, 0.4776, 0.3111, 0.4495, 0.3284, 0.7243,
#         0.3299, 1.1649, 0.2731, 1.6264, 0.3602, 1.4679, 0.3370, 0.5759, 0.3477,
#         0.3386, 0.9220, 0.3182, 0.3359, 0.4488, 0.4235, 0.3361, 0.3134, 1.9189,
#         0.5731, 0.3905, 0.2961, 0.5427, 0.3343, 0.3758, 0.2997, 0.3195, 0.4624,
#         0.5101, 0.4130, 0.4529, 0.3246, 0.3025, 0.7734, 0.4232, 0.4938, 0.3556,
#         0.4746, 1.3758, 0.3091, 1.2548])

# %%
# Generator
code = torch.FloatTensor(1, 256).normal_()
code = mean + std * code

out = vae.decode(code.cuda())
p = plt.imshow(out.view(64, 64).cpu().detach().numpy())
plt.colorbar(p)
plt.show()

# %%
part = out[0][0][0:32, 0:32]
t = F.interpolate(part.view(1, 1, 32, 32), 64)

out_part = vae(t)
plt.imshow(out_part[0].view(64, 64).cpu().detach().numpy())
plt.show()

out2 = out_part[0]
